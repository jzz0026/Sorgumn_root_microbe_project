# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.optimize import curve_fit
my_colors = [u'#1f77b4',
 u'#ff7f0e',
 u'#2ca02c',
 u'#d62728',
 u'#9467bd',
 u'#8c564b',
 u'#e377c2',
 u'#7f7f7f',
 u'#bcbd22',
 u'#17becf',            
 u'#fffa00',
 u'#000000',
 u'#b6ff9b',
 u'#005400',
 u'#ffc28c',
 u'#d69c68',
 u'#c1c1c1',
 u'#fbccff',
 u'#ff5e5e',
 u'#00edb2',
 u'#ffca1e',
 u'#933f3f',
 u'#f2f2f2']
col_known = ["#1 Mock community (direct amplification)",
    "#2 Mock community diluted (direct amplification)",
    "#4 Mock community (nested amplification)",
    "#5 Mock community diluted (nested amplification)",
    "#6 Field sample Grassl Rep 1 (Direct triplicate)",
    "#7 Field sample Grassl Rep 1 (Nested triplicate)",
    "#8  Field sample Grassl Rep 1 (Nested single)",
    "#9 Field sample 297155 Rep 2 (Direct triplicate)",
    "#10  Field sample 297155 Rep 2 (Nested triplicate)",
    "#11  Field sample 297155 Rep 3 (Direct triplicate)",
    "#12  Field sample 297155 Rep 3 (Nested triplicate)",
    "#13  Field sample 297155 Rep 3 (Nested single)"]
# %matplotlib inline
# !ls
# Out:
# 91_rare_20-100
# 93_alpha_collated
# 93_alpha_rare
# 93_rare_20-100
# Untitled.ipynb
# run_qiime_generate_data_for_make_curve.sh
# usearch_OTU_id91_count.biom
# usearch_OTU_id91_count.txt
# usearch_OTU_id92_count.biom
# usearch_OTU_id92_count.txt
# usearch_OTU_id93_count.biom
# usearch_OTU_id93_count.txt
# usearch_OTU_id94_count.biom
# usearch_OTU_id94_count.txt
# usearch_OTU_id95_count.biom
# usearch_OTU_id95_count.txt
# usearch_OTU_id96_count.biom
# usearch_OTU_id96_count.txt
# usearch_OTU_id97_count.biom
# usearch_OTU_id97_count.txt
# usearch_OTU_id98_count.biom
# usearch_OTU_id98_count.txt

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
import numpy as np
plt.style.use('seaborn')

df = pd.read_csv("93_alpha_collated/observed_species.txt",sep="\t",index_col=0)
sample_id = df.columns[2:]
df = df.replace("n/a",np.nan)

plt.figure(figsize=(10,5))
for i in np.arange(len(sample_id)):#each_sample = sample_id[2]
    each_sample = sample_id[i]
    dft = df.loc[:,["sequences per sample",each_sample]]
    dft = dft[dft.notnull().all(1)]
    dft = dft.astype("float")
    dftt = pd.DataFrame(dft.groupby("sequences per sample")[each_sample].mean()).reset_index()
    #dftt
    #plt.plot(dftt["sequences per sample"],dftt[each_sample],".",label=each_sample)
    #plt.legend()


    model = Pipeline([('poly', PolynomialFeatures(degree=9)),('Ridge', Ridge(fit_intercept=False,alpha=100))])
    grid_values = {'Ridge__alpha': [0.001,0.01,0.05,0.1,1,10,100]}
    grid_clf_model = GridSearchCV(model,grid_values,cv=5)
    #model.fit(list(dftt["sequences per sample"]),list(dftt[each_sample]))
    X = np.array(dftt["sequences per sample"]).reshape(-1,1)
    y = np.array(dftt[each_sample]).reshape(-1,1)
    y_pred = grid_clf_model.fit(X,y).predict(X).reshape(-1,1)
    
    
    plt.plot(X,y_pred,"-",label=each_sample,color=my_colors[i])
    plt.legend(bbox_to_anchor=(1.05, 1),loc=2)
# Out:
#                                sequences per sample  iteration  \
# alpha_rarefaction_10_0.txt                       10          0
# alpha_rarefaction_10_1.txt                       10          1
# alpha_rarefaction_10_2.txt                       10          2
# alpha_rarefaction_10_3.txt                       10          3
# alpha_rarefaction_10_4.txt                       10          4
# alpha_rarefaction_10_5.txt                       10          5
# alpha_rarefaction_10_6.txt                       10          6
# alpha_rarefaction_10_7.txt                       10          7
# alpha_rarefaction_10_8.txt                       10          8
# alpha_rarefaction_10_9.txt                       10          9
# alpha_rarefaction_10_10.txt                      10         10
# alpha_rarefaction_10_11.txt                      10         11
# alpha_rarefaction_10_12.txt                      10         12
# alpha_rarefaction_10_13.txt                      10         13
# alpha_rarefaction_10_14.txt                      10         14
# alpha_rarefaction_10_15.txt                      10         15
# alpha_rarefaction_10_16.txt                      10         16
# alpha_rarefaction_10_17.txt                      10         17
# alpha_rarefaction_10_18.txt                      10         18
# alpha_rarefaction_10_19.txt                      10         19
# alpha_rarefaction_10_20.txt                      10         20
# alpha_rarefaction_10_21.txt                      10         21
# alpha_rarefaction_10_22.txt                      10         22
# alpha_rarefaction_10_23.txt                      10         23
# alpha_rarefaction_10_24.txt                      10         24
# alpha_rarefaction_10_25.txt                      10         25
# alpha_rarefaction_10_26.txt                      10         26
# alpha_rarefaction_10_27.txt                      10         27
# alpha_rarefaction_10_28.txt                      10         28
# alpha_rarefaction_10_29.txt                      10         29
# ...                                             ...        ...
# alpha_rarefaction_1100_20.txt                  1100         20
# alpha_rarefaction_1100_21.txt                  1100         21
# alpha_rarefaction_1100_22.txt                  1100         22
# alpha_rarefaction_1100_23.txt                  1100         23
# alpha_rarefaction_1100_24.txt                  1100         24
# alpha_rarefaction_1100_25.txt                  1100         25
# alpha_rarefaction_1100_26.txt                  1100         26
# alpha_rarefaction_1100_27.txt                  1100         27
# alpha_rarefaction_1100_28.txt                  1100         28
# alpha_rarefaction_1100_29.txt                  1100         29
# alpha_rarefaction_1100_30.txt                  1100         30
# alpha_rarefaction_1100_31.txt                  1100         31
# alpha_rarefaction_1100_32.txt                  1100         32
# alpha_rarefaction_1100_33.txt                  1100         33
# alpha_rarefaction_1100_34.txt                  1100         34
# alpha_rarefaction_1100_35.txt                  1100         35
# alpha_rarefaction_1100_36.txt                  1100         36
# alpha_rarefaction_1100_37.txt                  1100         37
# alpha_rarefaction_1100_38.txt                  1100         38
# alpha_rarefaction_1100_39.txt                  1100         39
# alpha_rarefaction_1100_40.txt                  1100         40
# alpha_rarefaction_1100_41.txt                  1100         41
# alpha_rarefaction_1100_42.txt                  1100         42
# alpha_rarefaction_1100_43.txt                  1100         43
# alpha_rarefaction_1100_44.txt                  1100         44
# alpha_rarefaction_1100_45.txt                  1100         45
# alpha_rarefaction_1100_46.txt                  1100         46
# alpha_rarefaction_1100_47.txt                  1100         47
# alpha_rarefaction_1100_48.txt                  1100         48
# alpha_rarefaction_1100_49.txt                  1100         49
#
#                                Test4-AMFmix-2018_1  Test4-AMFmix-2018_2  \
# alpha_rarefaction_10_0.txt                     4.0                  3.0
# alpha_rarefaction_10_1.txt                     2.0                  3.0
# alpha_rarefaction_10_2.txt                     3.0                  2.0
# alpha_rarefaction_10_3.txt                     3.0                  3.0
# alpha_rarefaction_10_4.txt                     3.0                  2.0
# alpha_rarefaction_10_5.txt                     2.0                  3.0
# alpha_rarefaction_10_6.txt                     3.0                  2.0
# alpha_rarefaction_10_7.txt                     2.0                  2.0
# alpha_rarefaction_10_8.txt                     3.0                  3.0
# alpha_rarefaction_10_9.txt                     3.0                  2.0
# alpha_rarefaction_10_10.txt                    3.0                  3.0
# alpha_rarefaction_10_11.txt                    3.0                  3.0
# alpha_rarefaction_10_12.txt                    3.0                  3.0
# alpha_rarefaction_10_13.txt                    2.0                  2.0
# alpha_rarefaction_10_14.txt                    3.0                  3.0
# alpha_rarefaction_10_15.txt                    3.0                  3.0
# alpha_rarefaction_10_16.txt                    2.0                  3.0
# alpha_rarefaction_10_17.txt                    4.0                  3.0
# alpha_rarefaction_10_18.txt                    3.0                  3.0
# alpha_rarefaction_10_19.txt                    2.0                  3.0
# alpha_rarefaction_10_20.txt                    3.0                  3.0
# alpha_rarefaction_10_21.txt                    2.0                  3.0
# alpha_rarefaction_10_22.txt                    4.0                  3.0
# alpha_rarefaction_10_23.txt                    3.0                  3.0
# alpha_rarefaction_10_24.txt                    2.0                  3.0
# alpha_rarefaction_10_25.txt                    2.0                  2.0
# alpha_rarefaction_10_26.txt                    2.0                  3.0
# alpha_rarefaction_10_27.txt                    2.0                  2.0
# alpha_rarefaction_10_28.txt                    3.0                  4.0
# alpha_rarefaction_10_29.txt                    3.0                  3.0
# ...                                            ...                  ...
# alpha_rarefaction_1100_20.txt                  7.0                  7.0
# alpha_rarefaction_1100_21.txt                  7.0                  7.0
# alpha_rarefaction_1100_22.txt                  6.0                  7.0
# alpha_rarefaction_1100_23.txt                  6.0                  6.0
# alpha_rarefaction_1100_24.txt                  7.0                  7.0
# alpha_rarefaction_1100_25.txt                  6.0                  7.0
# alpha_rarefaction_1100_26.txt                  7.0                  7.0
# alpha_rarefaction_1100_27.txt                  6.0                  6.0
# alpha_rarefaction_1100_28.txt                  6.0                  6.0
# alpha_rarefaction_1100_29.txt                  7.0                  7.0
# alpha_rarefaction_1100_30.txt                  7.0                  7.0
# alpha_rarefaction_1100_31.txt                  7.0                  6.0
# alpha_rarefaction_1100_32.txt                  6.0                  7.0
# alpha_rarefaction_1100_33.txt                  6.0                  5.0
# alpha_rarefaction_1100_34.txt                  7.0                  7.0
# alpha_rarefaction_1100_35.txt                  7.0                  7.0
# alpha_rarefaction_1100_36.txt                  7.0                  7.0
# alpha_rarefaction_1100_37.txt                  6.0                  7.0
# alpha_rarefaction_1100_38.txt                  7.0                  7.0
# alpha_rarefaction_1100_39.txt                  7.0                  6.0
# alpha_rarefaction_1100_40.txt                  7.0                  7.0
# alpha_rarefaction_1100_41.txt                  7.0                  6.0
# alpha_rarefaction_1100_42.txt                  7.0                  7.0
# alpha_rarefaction_1100_43.txt                  7.0                  7.0
# alpha_rarefaction_1100_44.txt                  7.0                  6.0
# alpha_rarefaction_1100_45.txt                  6.0                  7.0
# alpha_rarefaction_1100_46.txt                  7.0                  6.0
# alpha_rarefaction_1100_47.txt                  6.0                  7.0
# alpha_rarefaction_1100_48.txt                  7.0                  5.0
# alpha_rarefaction_1100_49.txt                  7.0                  7.0
#
#                               Test4-AMFmix-2018_4  Test4-AMFmix-2018_5  \
# alpha_rarefaction_10_0.txt                    3.0                  2.0
# alpha_rarefaction_10_1.txt                    4.0                  2.0
# alpha_rarefaction_10_2.txt                    3.0                  3.0
# alpha_rarefaction_10_3.txt                    4.0                  2.0
# alpha_rarefaction_10_4.txt                    3.0                  3.0
# alpha_rarefaction_10_5.txt                    3.0                  3.0
# alpha_rarefaction_10_6.txt                    2.0                  2.0
# alpha_rarefaction_10_7.txt                    3.0                  3.0
# alpha_rarefaction_10_8.txt                    4.0                  2.0
# alpha_rarefaction_10_9.txt                    4.0                  3.0
# alpha_rarefaction_10_10.txt                   3.0                  2.0
# alpha_rarefaction_10_11.txt                   3.0                  2.0
# alpha_rarefaction_10_12.txt                   3.0                  3.0
# alpha_rarefaction_10_13.txt                   3.0                  3.0
# alpha_rarefaction_10_14.txt                   3.0                  3.0
# alpha_rarefaction_10_15.txt                   3.0                  3.0
# alpha_rarefaction_10_16.txt                   2.0                  3.0
# alpha_rarefaction_10_17.txt                   4.0                  3.0
# alpha_rarefaction_10_18.txt                   3.0                  3.0
# alpha_rarefaction_10_19.txt                   3.0                  3.0
# alpha_rarefaction_10_20.txt                   3.0                  2.0
# alpha_rarefaction_10_21.txt                   3.0                  2.0
# alpha_rarefaction_10_22.txt                   3.0                  2.0
# alpha_rarefaction_10_23.txt                   3.0                  3.0
# alpha_rarefaction_10_24.txt                   3.0                  2.0
# alpha_rarefaction_10_25.txt                   3.0                  2.0
# alpha_rarefaction_10_26.txt                   3.0                  2.0
# alpha_rarefaction_10_27.txt                   4.0                  3.0
# alpha_rarefaction_10_28.txt                   4.0                  3.0
# alpha_rarefaction_10_29.txt                   2.0                  3.0
# ...                                           ...                  ...
# alpha_rarefaction_1100_20.txt                 NaN                  6.0
# alpha_rarefaction_1100_21.txt                 NaN                  6.0
# alpha_rarefaction_1100_22.txt                 NaN                  5.0
# alpha_rarefaction_1100_23.txt                 NaN                  6.0
# alpha_rarefaction_1100_24.txt                 NaN                  6.0
# alpha_rarefaction_1100_25.txt                 NaN                  6.0
# alpha_rarefaction_1100_26.txt                 NaN                  6.0
# alpha_rarefaction_1100_27.txt                 NaN                  5.0
# alpha_rarefaction_1100_28.txt                 NaN                  6.0
# alpha_rarefaction_1100_29.txt                 NaN                  5.0
# alpha_rarefaction_1100_30.txt                 NaN                  5.0
# alpha_rarefaction_1100_31.txt                 NaN                  6.0
# alpha_rarefaction_1100_32.txt                 NaN                  6.0
# alpha_rarefaction_1100_33.txt                 NaN                  6.0
# alpha_rarefaction_1100_34.txt                 NaN                  6.0
# alpha_rarefaction_1100_35.txt                 NaN                  6.0
# alpha_rarefaction_1100_36.txt                 NaN                  6.0
# alpha_rarefaction_1100_37.txt                 NaN                  6.0
# alpha_rarefaction_1100_38.txt                 NaN                  6.0
# alpha_rarefaction_1100_39.txt                 NaN                  5.0
# alpha_rarefaction_1100_40.txt                 NaN                  6.0
# alpha_rarefaction_1100_41.txt                 NaN                  6.0
# alpha_rarefaction_1100_42.txt                 NaN                  5.0
# alpha_rarefaction_1100_43.txt                 NaN                  6.0
# alpha_rarefaction_1100_44.txt                 NaN                  6.0
# alpha_rarefaction_1100_45.txt                 NaN                  6.0
# alpha_rarefaction_1100_46.txt                 NaN                  6.0
# alpha_rarefaction_1100_47.txt                 NaN                  6.0
# alpha_rarefaction_1100_48.txt                 NaN                  5.0
# alpha_rarefaction_1100_49.txt                 NaN                  6.0
#
#                                Test4-AMFmix-2018_6 Test4-AMFmix-2018_7  \
# alpha_rarefaction_10_0.txt                     4.0                 3.0
# alpha_rarefaction_10_1.txt                     2.0                 6.0
# alpha_rarefaction_10_2.txt                     3.0                 4.0
# alpha_rarefaction_10_3.txt                     3.0                 5.0
# alpha_rarefaction_10_4.txt                     3.0                 6.0
# alpha_rarefaction_10_5.txt                     3.0                 4.0
# alpha_rarefaction_10_6.txt                     4.0                 3.0
# alpha_rarefaction_10_7.txt                     5.0                 5.0
# alpha_rarefaction_10_8.txt                     2.0                 6.0
# alpha_rarefaction_10_9.txt                     5.0                 3.0
# alpha_rarefaction_10_10.txt                    3.0                 4.0
# alpha_rarefaction_10_11.txt                    3.0                 3.0
# alpha_rarefaction_10_12.txt                    3.0                 5.0
# alpha_rarefaction_10_13.txt                    2.0                 3.0
# alpha_rarefaction_10_14.txt                    2.0                 5.0
# alpha_rarefaction_10_15.txt                    3.0                 5.0
# alpha_rarefaction_10_16.txt                    2.0                 4.0
# alpha_rarefaction_10_17.txt                    3.0                 3.0
# alpha_rarefaction_10_18.txt                    4.0                 5.0
# alpha_rarefaction_10_19.txt                    4.0                 5.0
# alpha_rarefaction_10_20.txt                    4.0                 3.0
# alpha_rarefaction_10_21.txt                    3.0                 6.0
# alpha_rarefaction_10_22.txt                    5.0                 4.0
# alpha_rarefaction_10_23.txt                    5.0                 5.0
# alpha_rarefaction_10_24.txt                    3.0                 3.0
# alpha_rarefaction_10_25.txt                    5.0                 4.0
# alpha_rarefaction_10_26.txt                    5.0                 3.0
# alpha_rarefaction_10_27.txt                    5.0                 4.0
# alpha_rarefaction_10_28.txt                    4.0                 5.0
# alpha_rarefaction_10_29.txt                    4.0                 4.0
# ...                                            ...                 ...
# alpha_rarefaction_1100_20.txt                 19.0                 NaN
# alpha_rarefaction_1100_21.txt                 19.0                 NaN
# alpha_rarefaction_1100_22.txt                 19.0                 NaN
# alpha_rarefaction_1100_23.txt                 19.0                 NaN
# alpha_rarefaction_1100_24.txt                 19.0                 NaN
# alpha_rarefaction_1100_25.txt                 19.0                 NaN
# alpha_rarefaction_1100_26.txt                 19.0                 NaN
# alpha_rarefaction_1100_27.txt                 19.0                 NaN
# alpha_rarefaction_1100_28.txt                 19.0                 NaN
# alpha_rarefaction_1100_29.txt                 19.0                 NaN
# alpha_rarefaction_1100_30.txt                 19.0                 NaN
# alpha_rarefaction_1100_31.txt                 19.0                 NaN
# alpha_rarefaction_1100_32.txt                 19.0                 NaN
# alpha_rarefaction_1100_33.txt                 19.0                 NaN
# alpha_rarefaction_1100_34.txt                 19.0                 NaN
# alpha_rarefaction_1100_35.txt                 19.0                 NaN
# alpha_rarefaction_1100_36.txt                 19.0                 NaN
# alpha_rarefaction_1100_37.txt                 19.0                 NaN
# alpha_rarefaction_1100_38.txt                 19.0                 NaN
# alpha_rarefaction_1100_39.txt                 19.0                 NaN
# alpha_rarefaction_1100_40.txt                 19.0                 NaN
# alpha_rarefaction_1100_41.txt                 19.0                 NaN
# alpha_rarefaction_1100_42.txt                 19.0                 NaN
# alpha_rarefaction_1100_43.txt                 19.0                 NaN
# alpha_rarefaction_1100_44.txt                 19.0                 NaN
# alpha_rarefaction_1100_45.txt                 19.0                 NaN
# alpha_rarefaction_1100_46.txt                 19.0                 NaN
# alpha_rarefaction_1100_47.txt                 19.0                 NaN
# alpha_rarefaction_1100_48.txt                 19.0                 NaN
# alpha_rarefaction_1100_49.txt                 19.0                 NaN
#
#                               Test4-AMFmix-2018_8  Test4-AMFmix-2018_10  \
# alpha_rarefaction_10_0.txt                    4.0                   4.0
# alpha_rarefaction_10_1.txt                    5.0                   6.0
# alpha_rarefaction_10_2.txt                    5.0                   5.0
# alpha_rarefaction_10_3.txt                    6.0                   7.0
# alpha_rarefaction_10_4.txt                    4.0                   6.0
# alpha_rarefaction_10_5.txt                    4.0                   6.0
# alpha_rarefaction_10_6.txt                    3.0                   5.0
# alpha_rarefaction_10_7.txt                    4.0                   8.0
# alpha_rarefaction_10_8.txt                    3.0                   6.0
# alpha_rarefaction_10_9.txt                    3.0                   7.0
# alpha_rarefaction_10_10.txt                   3.0                   6.0
# alpha_rarefaction_10_11.txt                   5.0                   6.0
# alpha_rarefaction_10_12.txt                   4.0                   8.0
# alpha_rarefaction_10_13.txt                   5.0                   7.0
# alpha_rarefaction_10_14.txt                   3.0                   7.0
# alpha_rarefaction_10_15.txt                   4.0                   7.0
# alpha_rarefaction_10_16.txt                   4.0                   8.0
# alpha_rarefaction_10_17.txt                   4.0                   5.0
# alpha_rarefaction_10_18.txt                   3.0                   4.0
# alpha_rarefaction_10_19.txt                   4.0                   6.0
# alpha_rarefaction_10_20.txt                   6.0                   6.0
# alpha_rarefaction_10_21.txt                   5.0                   6.0
# alpha_rarefaction_10_22.txt                   5.0                   6.0
# alpha_rarefaction_10_23.txt                   5.0                   5.0
# alpha_rarefaction_10_24.txt                   4.0                   6.0
# alpha_rarefaction_10_25.txt                   4.0                   7.0
# alpha_rarefaction_10_26.txt                   4.0                   5.0
# alpha_rarefaction_10_27.txt                   4.0                   8.0
# alpha_rarefaction_10_28.txt                   3.0                   6.0
# alpha_rarefaction_10_29.txt                   3.0                   7.0
# ...                                           ...                   ...
# alpha_rarefaction_1100_20.txt                 NaN                  17.0
# alpha_rarefaction_1100_21.txt                 NaN                  17.0
# alpha_rarefaction_1100_22.txt                 NaN                  17.0
# alpha_rarefaction_1100_23.txt                 NaN                  17.0
# alpha_rarefaction_1100_24.txt                 NaN                  17.0
# alpha_rarefaction_1100_25.txt                 NaN                  17.0
# alpha_rarefaction_1100_26.txt                 NaN                  17.0
# alpha_rarefaction_1100_27.txt                 NaN                  17.0
# alpha_rarefaction_1100_28.txt                 NaN                  17.0
# alpha_rarefaction_1100_29.txt                 NaN                  17.0
# alpha_rarefaction_1100_30.txt                 NaN                  17.0
# alpha_rarefaction_1100_31.txt                 NaN                  17.0
# alpha_rarefaction_1100_32.txt                 NaN                  17.0
# alpha_rarefaction_1100_33.txt                 NaN                  17.0
# alpha_rarefaction_1100_34.txt                 NaN                  17.0
# alpha_rarefaction_1100_35.txt                 NaN                  17.0
# alpha_rarefaction_1100_36.txt                 NaN                  17.0
# alpha_rarefaction_1100_37.txt                 NaN                  17.0
# alpha_rarefaction_1100_38.txt                 NaN                  17.0
# alpha_rarefaction_1100_39.txt                 NaN                  17.0
# alpha_rarefaction_1100_40.txt                 NaN                  17.0
# alpha_rarefaction_1100_41.txt                 NaN                  17.0
# alpha_rarefaction_1100_42.txt                 NaN                  17.0
# alpha_rarefaction_1100_43.txt                 NaN                  17.0
# alpha_rarefaction_1100_44.txt                 NaN                  17.0
# alpha_rarefaction_1100_45.txt                 NaN                  17.0
# alpha_rarefaction_1100_46.txt                 NaN                  17.0
# alpha_rarefaction_1100_47.txt                 NaN                  17.0
# alpha_rarefaction_1100_48.txt                 NaN                  17.0
# alpha_rarefaction_1100_49.txt                 NaN                  17.0
#
#                               Test4-AMFmix-2018_11 Test4-AMFmix-2018_12  \
# alpha_rarefaction_10_0.txt                     7.0                  7.0
# alpha_rarefaction_10_1.txt                     6.0                  5.0
# alpha_rarefaction_10_2.txt                     6.0                  7.0
# alpha_rarefaction_10_3.txt                     6.0                  4.0
# alpha_rarefaction_10_4.txt                     8.0                  4.0
# alpha_rarefaction_10_5.txt                     7.0                  6.0
# alpha_rarefaction_10_6.txt                     5.0                  6.0
# alpha_rarefaction_10_7.txt                     4.0                  6.0
# alpha_rarefaction_10_8.txt                     8.0                  6.0
# alpha_rarefaction_10_9.txt                     5.0                  5.0
# alpha_rarefaction_10_10.txt                    9.0                  4.0
# alpha_rarefaction_10_11.txt                    4.0                  6.0
# alpha_rarefaction_10_12.txt                    6.0                  4.0
# alpha_rarefaction_10_13.txt                    7.0                  4.0
# alpha_rarefaction_10_14.txt                    6.0                  5.0
# alpha_rarefaction_10_15.txt                    6.0                  4.0
# alpha_rarefaction_10_16.txt                    6.0                  6.0
# alpha_rarefaction_10_17.txt                    7.0                  5.0
# alpha_rarefaction_10_18.txt                    6.0                  4.0
# alpha_rarefaction_10_19.txt                    8.0                  5.0
# alpha_rarefaction_10_20.txt                    6.0                  8.0
# alpha_rarefaction_10_21.txt                    7.0                  6.0
# alpha_rarefaction_10_22.txt                    7.0                  5.0
# alpha_rarefaction_10_23.txt                    6.0                  5.0
# alpha_rarefaction_10_24.txt                    5.0                  4.0
# alpha_rarefaction_10_25.txt                    6.0                  5.0
# alpha_rarefaction_10_26.txt                    7.0                  5.0
# alpha_rarefaction_10_27.txt                    4.0                  5.0
# alpha_rarefaction_10_28.txt                    8.0                  5.0
# alpha_rarefaction_10_29.txt                    5.0                  3.0
# ...                                            ...                  ...
# alpha_rarefaction_1100_20.txt                  NaN                  NaN
# alpha_rarefaction_1100_21.txt                  NaN                  NaN
# alpha_rarefaction_1100_22.txt                  NaN                  NaN
# alpha_rarefaction_1100_23.txt                  NaN                  NaN
# alpha_rarefaction_1100_24.txt                  NaN                  NaN
# alpha_rarefaction_1100_25.txt                  NaN                  NaN
# alpha_rarefaction_1100_26.txt                  NaN                  NaN
# alpha_rarefaction_1100_27.txt                  NaN                  NaN
# alpha_rarefaction_1100_28.txt                  NaN                  NaN
# alpha_rarefaction_1100_29.txt                  NaN                  NaN
# alpha_rarefaction_1100_30.txt                  NaN                  NaN
# alpha_rarefaction_1100_31.txt                  NaN                  NaN
# alpha_rarefaction_1100_32.txt                  NaN                  NaN
# alpha_rarefaction_1100_33.txt                  NaN                  NaN
# alpha_rarefaction_1100_34.txt                  NaN                  NaN
# alpha_rarefaction_1100_35.txt                  NaN                  NaN
# alpha_rarefaction_1100_36.txt                  NaN                  NaN
# alpha_rarefaction_1100_37.txt                  NaN                  NaN
# alpha_rarefaction_1100_38.txt                  NaN                  NaN
# alpha_rarefaction_1100_39.txt                  NaN                  NaN
# alpha_rarefaction_1100_40.txt                  NaN                  NaN
# alpha_rarefaction_1100_41.txt                  NaN                  NaN
# alpha_rarefaction_1100_42.txt                  NaN                  NaN
# alpha_rarefaction_1100_43.txt                  NaN                  NaN
# alpha_rarefaction_1100_44.txt                  NaN                  NaN
# alpha_rarefaction_1100_45.txt                  NaN                  NaN
# alpha_rarefaction_1100_46.txt                  NaN                  NaN
# alpha_rarefaction_1100_47.txt                  NaN                  NaN
# alpha_rarefaction_1100_48.txt                  NaN                  NaN
# alpha_rarefaction_1100_49.txt                  NaN                  NaN
#
#                               Test4-AMFmix-2018_13
# alpha_rarefaction_10_0.txt                     3.0
# alpha_rarefaction_10_1.txt                     2.0
# alpha_rarefaction_10_2.txt                     6.0
# alpha_rarefaction_10_3.txt                     5.0
# alpha_rarefaction_10_4.txt                     5.0
# alpha_rarefaction_10_5.txt                     7.0
# alpha_rarefaction_10_6.txt                     6.0
# alpha_rarefaction_10_7.txt                     5.0
# alpha_rarefaction_10_8.txt                     6.0
# alpha_rarefaction_10_9.txt                     7.0
# alpha_rarefaction_10_10.txt                    5.0
# alpha_rarefaction_10_11.txt                    6.0
# alpha_rarefaction_10_12.txt                    4.0
# alpha_rarefaction_10_13.txt                    6.0
# alpha_rarefaction_10_14.txt                    6.0
# alpha_rarefaction_10_15.txt                    5.0
# alpha_rarefaction_10_16.txt                    5.0
# alpha_rarefaction_10_17.txt                    6.0
# alpha_rarefaction_10_18.txt                    4.0
# alpha_rarefaction_10_19.txt                    4.0
# alpha_rarefaction_10_20.txt                    4.0
# alpha_rarefaction_10_21.txt                    4.0
# alpha_rarefaction_10_22.txt                    6.0
# alpha_rarefaction_10_23.txt                    6.0
# alpha_rarefaction_10_24.txt                    5.0
# alpha_rarefaction_10_25.txt                    5.0
# alpha_rarefaction_10_26.txt                    6.0
# alpha_rarefaction_10_27.txt                    4.0
# alpha_rarefaction_10_28.txt                    5.0
# alpha_rarefaction_10_29.txt                    5.0
# ...                                            ...
# alpha_rarefaction_1100_20.txt                  NaN
# alpha_rarefaction_1100_21.txt                  NaN
# alpha_rarefaction_1100_22.txt                  NaN
# alpha_rarefaction_1100_23.txt                  NaN
# alpha_rarefaction_1100_24.txt                  NaN
# alpha_rarefaction_1100_25.txt                  NaN
# alpha_rarefaction_1100_26.txt                  NaN
# alpha_rarefaction_1100_27.txt                  NaN
# alpha_rarefaction_1100_28.txt                  NaN
# alpha_rarefaction_1100_29.txt                  NaN
# alpha_rarefaction_1100_30.txt                  NaN
# alpha_rarefaction_1100_31.txt                  NaN
# alpha_rarefaction_1100_32.txt                  NaN
# alpha_rarefaction_1100_33.txt                  NaN
# alpha_rarefaction_1100_34.txt                  NaN
# alpha_rarefaction_1100_35.txt                  NaN
# alpha_rarefaction_1100_36.txt                  NaN
# alpha_rarefaction_1100_37.txt                  NaN
# alpha_rarefaction_1100_38.txt                  NaN
# alpha_rarefaction_1100_39.txt                  NaN
# alpha_rarefaction_1100_40.txt                  NaN
# alpha_rarefaction_1100_41.txt                  NaN
# alpha_rarefaction_1100_42.txt                  NaN
# alpha_rarefaction_1100_43.txt                  NaN
# alpha_rarefaction_1100_44.txt                  NaN
# alpha_rarefaction_1100_45.txt                  NaN
# alpha_rarefaction_1100_46.txt                  NaN
# alpha_rarefaction_1100_47.txt                  NaN
# alpha_rarefaction_1100_48.txt                  NaN
# alpha_rarefaction_1100_49.txt                  NaN
#
# [5500 rows x 13 columns]

# %%
df.columns #= list(df.columns[:2]) + col_known
# Out:
# Index(['sequences per sample', 'iteration', 'Test4-AMFmix-2018_1',
#        'Test4-AMFmix-2018_2', 'Test4-AMFmix-2018_4', 'Test4-AMFmix-2018_5',
#        'Test4-AMFmix-2018_6', 'Test4-AMFmix-2018_7', 'Test4-AMFmix-2018_8',
#        'Test4-AMFmix-2018_10', 'Test4-AMFmix-2018_11', 'Test4-AMFmix-2018_12',
#        'Test4-AMFmix-2018_13'],
#       dtype='object')

# %%
list(df.columns[:2]) + col_known
# Out:
# ['sequences per sample',
#  'iteration',
#  '#1 Mock community (direct amplification)',
#  '#2 Mock community diluted (direct amplification)',
#  '#4 Mock community (nested amplification)',
#  '#5 Mock community diluted (nested amplification)',
#  '#6 Field sample Grassl Rep 1 (Direct triplicate)',
#  '#7 Field sample Grassl Rep 1 (Nested triplicate)',
#  '#8  Field sample Grassl Rep 1 (Nested single)',
#  '#9 Field sample 297155 Rep 2 (Direct triplicate)',
#  '#10  Field sample 297155 Rep 2 (Nested triplicate)',
#  '#11  Field sample 297155 Rep 3 (Direct triplicate)',
#  '#12  Field sample 297155 Rep 3 (Nested triplicate)',
#  '#13  Field sample 297155 Rep 3 (Nested single)']
