# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.ticker as mtick

# %matplotlib inline

# %%
df = pd.read_csv("2565956580_Sorghum_microbiome_072115-103_1_header_shuf_rand80000.txt",header=None,sep="\t")
df[[2,3]] = df[[2,3]].astype("float")
plt.figure(figsize=(12, 6))
plt.scatter(df[2],df[3],s=1,alpha=1)
